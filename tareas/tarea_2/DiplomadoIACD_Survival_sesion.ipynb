# %% [markdown]
# # Sesión sobre el uso de redes neuronales en análisis de supervivencia
#
# En las últimas sesiones hemos estudiado el análisis de supervivencia, particularmente el *modelo de riesgo proporcional de Cox*. Hemos visto la necesidad de usar optimizadores estocásticos como SGD y sus variantes para ajustar este modelo, y también discutimos la forma de manejar los conjuntos de riesgo a la hora de implementar SGD en el análisis de supervivencia. En este notebook veremos cómo extender estos modelos con el uso de redes neuronales, en particular estudiaremos la paquetería `PyCox`. Quedará como trabajo de clase-tarea implementar los métodos vistos con una base de datos real como `SUPPORT`, `METABRIC`, `Rot. & GBSG` o `FLCHAIN`.

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from pycox.models import CoxPH
from pycox.evaluation import EvalSurv

# %%
# Generar datos simulados (tiempos de ocurrencia de acuerdo a una distribución Weibull)

def true_log_risk_nonlinear(x, lambda_max=5.0, r=0.5):
    # x: array shape (N, d)
    return np.log(lambda_max) * np.exp(
        -(x[:, 0]**2 + x[:, 1]**2) / (2 * r**2)
    )

def simulate_event_times_nonlinear(x, k=1.5, lambda0=0.2, lambda_max=5.0, r=0.5, seed=None):
    rng = np.random.default_rng(seed)

    h = true_log_risk_nonlinear(x, lambda_max=lambda_max, r=r)
    lam = lambda0 * np.exp(h / k)

    u = rng.uniform(size=x.shape[0])
    e = -np.log(u)  # Exp(1)

    t = e**(1 / k) / lam

    return t, h, lam

# Applying censoring

def find_trial_end_time(t_event, target_event_rate=0.9):
    """
    Choose T0 so that approximately target_event_rate proportion
    of individuals have an observed event.

    Z_i = min(T_i, T0)
    status_i = 1{T_i <= T0}
    """
    return np.quantile(t_event, target_event_rate)


def apply_censoring(t_event, trial_end_time):
    """
    Apply administrative right censoring at fixed trial end time T0.
    """
    time_observed = np.minimum(t_event, trial_end_time)
    status = (t_event <= trial_end_time).astype(np.float32)

    # Same censoring time for every individual
    censoring = np.full_like(t_event, trial_end_time, dtype=np.float32)

    return time_observed, status, censoring

# Generation

def generate_split_nonlinear(n, d=10, lambda0=0.2, lambda_max=5.0, r=0.5,
                   trial_end_time=None, seed=1234):
    rng = np.random.default_rng(seed)

    x = rng.uniform(-1.0, 1.0, size=(n, d)).astype(np.float32)

    t_event, h_true, rate = simulate_event_times_nonlinear(
        x,
        lambda0=lambda0,
        lambda_max=lambda_max,
        r=r,
        seed=seed + 1
    )

    time_obs, status, censoring = apply_censoring(
        t_event,
        trial_end_time
    )

    return {
        "x": x,
        "time": time_obs.astype(np.float32),
        "status": status.astype(np.float32),
        "h_true": h_true.astype(np.float32),
        "t_event": t_event.astype(np.float32),
        "censoring": censoring.astype(np.float32),
        "rate": rate.astype(np.float32),
    }

# %%
N_train, N_val, N_test = 4000, 1000, 1000
d = 10
target_event_rate = 0.9
lambda0=0.02
lambda_max = 5.0
r = 0.5
rng_tmp = np.random.default_rng(2024)
x_tmp = rng_tmp.uniform(-1.0, 1.0, size=(N_train, d)).astype(np.float32)

# %%
t_tmp, h_tmp, _ = simulate_event_times_nonlinear(
    x_tmp,
    lambda0=lambda0,
    seed=2025
)

trial_end_time = find_trial_end_time(
    t_tmp,
    target_event_rate=target_event_rate
)

print("Trial end time T0:", trial_end_time)
# Out:
# Trial end time T0: 62.367359078232106

# %%
train = generate_split_nonlinear(
    N_train,
    d=d,
    lambda0=lambda0,
    lambda_max=lambda_max,
    r=r,
    trial_end_time=trial_end_time,
    seed=10
)

val = generate_split_nonlinear(
    N_val,
    d=d,
    lambda0=lambda0,
    lambda_max=lambda_max,
    r=r,
    trial_end_time=trial_end_time,
    seed=20
)

test = generate_split_nonlinear(
    N_test,
    d=d,
    lambda0=lambda0,
    lambda_max=lambda_max,
    r=r,
    trial_end_time=trial_end_time,
    seed=30
)

print("Event rate train:", train["status"].mean())
print("Event rate val:  ", val["status"].mean())
print("Event rate test: ", test["status"].mean())
# Out:
# Event rate train: 0.894
# Event rate val:   0.89
# Event rate test:  0.884

# %%
# Modelo DeepSurv

class DeepSurvRisk(nn.Module):

    def __init__(
        self,
        input_dim,
        hidden_dims=(32, 32, 32),
        dropout=0.0
    ):
        super().__init__()

        layers = []
        prev_dim = input_dim

        for h in hidden_dims:

            layers.append(
                nn.Linear(prev_dim, h)
            )

            layers.append(
                nn.Tanh()
            )

            if dropout > 0:
                layers.append(
                    nn.Dropout(dropout)
                )

            prev_dim = h

        # Un score de riesgo por individuo
        layers.append(
            nn.Linear(prev_dim, 1)
        )

        self.network = nn.Sequential(*layers)

    def forward(self, x):
        return self.network(x)

# %%
# Número de covariables
input_dim = train["x"].shape[1]


# Crear la red
net = DeepSurvRisk(
    input_dim=input_dim,
    hidden_dims=(32, 32, 32),
    dropout=0.0
)


# Crear el modelo Cox de PyCox
model = CoxPH(
    net,
    optimizer=torch.optim.Adam
)


# Learning rate
model.optimizer.set_lr(1e-3)

# %%
x_train = train["x"].astype("float32")
time_train = train["time"].astype("float32")
status_train = train["status"].astype("float32")

x_val = val["x"].astype("float32")
time_val = val["time"].astype("float32")
status_val = val["status"].astype("float32")

# %%
log = model.fit(
    input=x_train,
    target=(time_train, status_train),
    batch_size=64,
    epochs=100,
    val_data=(
        x_val,
        (time_val, status_val)
    ),
    verbose=True
)
# Out:
# 0:	[0s / 0s],		train_loss: 3.4296,	val_loss: 6.1838
# 1:	[0s / 0s],		train_loss: 3.4293,	val_loss: 6.1822
# 2:	[0s / 0s],		train_loss: 3.4284,	val_loss: 6.1828
# 3:	[0s / 0s],		train_loss: 3.4284,	val_loss: 6.1843
# 4:	[0s / 0s],		train_loss: 3.4282,	val_loss: 6.1829
# 5:	[0s / 0s],		train_loss: 3.4265,	val_loss: 6.1828
# 6:	[0s / 0s],		train_loss: 3.4264,	val_loss: 6.1816
# 7:	[0s / 0s],		train_loss: 3.4241,	val_loss: 6.1809
# 8:	[0s / 0s],		train_loss: 3.4227,	val_loss: 6.1789
# 9:	[0s / 0s],		train_loss: 3.4200,	val_loss: 6.1710
# 10:	[0s / 0s],		train_loss: 3.4143,	val_loss: 6.1613
# 11:	[0s / 0s],		train_loss: 3.3947,	val_loss: 6.1338
# 12:	[0s / 0s],		train_loss: 3.3755,	val_loss: 6.1113
# 13:	[0s / 0s],		train_loss: 3.3626,	val_loss: 6.1050
# 14:	[0s / 0s],		train_loss: 3.3615,	val_loss: 6.1007
# 15:	[0s / 0s],		train_loss: 3.3580,	val_loss: 6.1087
# 16:	[0s / 0s],		train_loss: 3.3584,	val_loss: 6.1013
# 17:	[0s / 0s],		train_loss: 3.3533,	val_loss: 6.0985
# 18:	[0s / 1s],		train_loss: 3.3574,	val_loss: 6.1027
# 19:	[0s / 1s],		train_loss: 3.3530,	val_loss: 6.1021
# 20:	[0s / 1s],		train_loss: 3.3512,	val_loss: 6.1012
# 21:	[0s / 1s],		train_loss: 3.3557,	val_loss: 6.1002
# 22:	[0s / 1s],		train_loss: 3.3528,	val_loss: 6.0976
# 23:	[0s / 1s],		train_loss: 3.3538,	val_loss: 6.0974
# 24:	[0s / 1s],		train_loss: 3.3507,	val_loss: 6.0951
# 25:	[0s / 1s],		train_loss: 3.3529,	val_loss: 6.0997
# 26:	[0s / 1s],		train_loss: 3.3522,	val_loss: 6.0999
# 27:	[0s / 1s],		train_loss: 3.3510,	val_loss: 6.0990
# 28:	[0s / 1s],		train_loss: 3.3475,	val_loss: 6.0941
# 29:	[0s / 1s],		train_loss: 3.3482,	val_loss: 6.0971
# 30:	[0s / 1s],		train_loss: 3.3516,	val_loss: 6.0998
# 31:	[0s / 1s],		train_loss: 3.3493,	val_loss: 6.0949
# 32:	[0s / 1s],		train_loss: 3.3493,	val_loss: 6.0962
# 33:	[0s / 1s],		train_loss: 3.3515,	val_loss: 6.0951
# 34:	[0s / 1s],		train_loss: 3.3468,	val_loss: 6.1032
# 35:	[0s / 2s],		train_loss: 3.3488,	val_loss: 6.0953
# 36:	[0s / 2s],		train_loss: 3.3474,	val_loss: 6.1000
# 37:	[0s / 2s],		train_loss: 3.3493,	val_loss: 6.0972
# 38:	[0s / 2s],		train_loss: 3.3453,	val_loss: 6.0968
# 39:	[0s / 2s],		train_loss: 3.3469,	val_loss: 6.0948
# 40:	[0s / 2s],		train_loss: 3.3459,	val_loss: 6.0986
# 41:	[0s / 2s],		train_loss: 3.3475,	val_loss: 6.0978
# 42:	[0s / 2s],		train_loss: 3.3476,	val_loss: 6.0990
# 43:	[0s / 2s],		train_loss: 3.3452,	val_loss: 6.1021
# 44:	[0s / 2s],		train_loss: 3.3488,	val_loss: 6.1009
# 45:	[0s / 2s],		train_loss: 3.3438,	val_loss: 6.0941
# 46:	[0s / 2s],		train_loss: 3.3445,	val_loss: 6.1090
# 47:	[0s / 2s],		train_loss: 3.3454,	val_loss: 6.1004
# 48:	[0s / 2s],		train_loss: 3.3419,	val_loss: 6.0963
# 49:	[0s / 2s],		train_loss: 3.3453,	val_loss: 6.0962
# 50:	[0s / 2s],		train_loss: 3.3440,	val_loss: 6.0969
# 51:	[0s / 2s],		train_loss: 3.3446,	val_loss: 6.0981
# 52:	[0s / 2s],		train_loss: 3.3424,	val_loss: 6.1002
# 53:	[0s / 2s],		train_loss: 3.3426,	val_loss: 6.0968
# 54:	[0s / 2s],		train_loss: 3.3422,	val_loss: 6.0971
# 55:	[0s / 3s],		train_loss: 3.3456,	val_loss: 6.0981
# 56:	[0s / 3s],		train_loss: 3.3413,	val_loss: 6.0988
# 57:	[0s / 3s],		train_loss: 3.3428,	val_loss: 6.1008
# 58:	[0s / 3s],		train_loss: 3.3423,	val_loss: 6.0970
# 59:	[0s / 3s],		train_loss: 3.3426,	val_loss: 6.1015
# 60:	[0s / 3s],		train_loss: 3.3410,	val_loss: 6.0949
# 61:	[0s / 3s],		train_loss: 3.3426,	val_loss: 6.1052
# 62:	[0s / 3s],		train_loss: 3.3395,	val_loss: 6.1024
# 63:	[0s / 3s],		train_loss: 3.3395,	val_loss: 6.1066
# 64:	[0s / 3s],		train_loss: 3.3414,	val_loss: 6.1010
# 65:	[0s / 3s],		train_loss: 3.3409,	val_loss: 6.1047
# 66:	[0s / 3s],		train_loss: 3.3400,	val_loss: 6.1024
# 67:	[0s / 3s],		train_loss: 3.3385,	val_loss: 6.1010
# 68:	[0s / 3s],		train_loss: 3.3402,	val_loss: 6.1035
# 69:	[0s / 3s],		train_loss: 3.3361,	val_loss: 6.1014
# 70:	[0s / 3s],		train_loss: 3.3388,	val_loss: 6.1069
# 71:	[0s / 3s],		train_loss: 3.3367,	val_loss: 6.1096
# 72:	[0s / 4s],		train_loss: 3.3351,	val_loss: 6.1038
# 73:	[0s / 4s],		train_loss: 3.3401,	val_loss: 6.0996
# 74:	[0s / 4s],		train_loss: 3.3364,	val_loss: 6.1025
# 75:	[0s / 4s],		train_loss: 3.3345,	val_loss: 6.1023
# 76:	[0s / 4s],		train_loss: 3.3360,	val_loss: 6.0995
# 77:	[0s / 4s],		train_loss: 3.3337,	val_loss: 6.1012
# 78:	[0s / 4s],		train_loss: 3.3337,	val_loss: 6.1013
# 79:	[0s / 4s],		train_loss: 3.3361,	val_loss: 6.1055
# 80:	[0s / 4s],		train_loss: 3.3340,	val_loss: 6.1018
# 81:	[0s / 4s],		train_loss: 3.3304,	val_loss: 6.1074
# 82:	[0s / 4s],		train_loss: 3.3362,	val_loss: 6.1052
# 83:	[0s / 5s],		train_loss: 3.3325,	val_loss: 6.1064
# 84:	[0s / 5s],		train_loss: 3.3340,	val_loss: 6.1011
# 85:	[0s / 5s],		train_loss: 3.3345,	val_loss: 6.1064
# 86:	[0s / 5s],		train_loss: 3.3295,	val_loss: 6.1064
# 87:	[0s / 5s],		train_loss: 3.3318,	val_loss: 6.1040
# 88:	[0s / 5s],		train_loss: 3.3306,	val_loss: 6.1070
# 89:	[0s / 5s],		train_loss: 3.3315,	val_loss: 6.1079
# 90:	[0s / 5s],		train_loss: 3.3300,	val_loss: 6.1063
# 91:	[0s / 5s],		train_loss: 3.3280,	val_loss: 6.1109
# 92:	[0s / 5s],		train_loss: 3.3277,	val_loss: 6.1085
# 93:	[0s / 5s],		train_loss: 3.3300,	val_loss: 6.1073
# 94:	[0s / 5s],		train_loss: 3.3247,	val_loss: 6.1115
# 95:	[0s / 5s],		train_loss: 3.3264,	val_loss: 6.1098
# 96:	[0s / 6s],		train_loss: 3.3276,	val_loss: 6.1065
# 97:	[0s / 6s],		train_loss: 3.3258,	val_loss: 6.1055
# 98:	[0s / 6s],		train_loss: 3.3299,	val_loss: 6.1085
# 99:	[0s / 6s],		train_loss: 3.3280,	val_loss: 6.1098

# %%
log.plot()
# Out:
# <Axes: >

# %%
# 1. Estimación de Breslow con entrenamiento
model.compute_baseline_hazards()

# 2. Curvas de supervivencia para test
x_test = test["x"].astype("float32")
time_test = test["time"]
status_test = test["status"]

surv_test = model.predict_surv_df(x_test)

# 3. Graficar cinco individuos
surv_test.iloc[:, :5].plot(
    figsize=(8, 5),
    drawstyle="steps-post"
)

plt.xlabel("Tiempo")
plt.ylabel("Probabilidad de supervivencia")
plt.title("Curvas de supervivencia estimadas")
plt.ylim(0, 1)
plt.grid(True)
plt.show()

# %%
ev = EvalSurv(
    surv_test,
    time_test,
    status_test
)

c_index = ev.concordance_td()

print("C-index PyCox:", c_index)
# Out:
# C-index PyCox: 0.6009100501187022

# %% [markdown]
# ## Trabajo de clase
#
# Seleccione **una** de las siguientes bases de datos:
#
# - SUPPORT
# - METABRIC
# - Rotterdam & GBSG
# - FLCHAIN
#
# ### Instrucciones
#
# 1. Identifique las covariables, el tiempo observado y el indicador de evento.
#
# 2. Divida la base de datos en conjuntos de:
#    - Entrenamiento
#    - Validación
#    - Prueba
#
# 3. Ajuste los siguientes modelos utilizando la misma partición de los datos:
#    - Modelo de riesgos proporcionales de Cox tradicional.
#    - Modelo DeepSurv utilizando PyCox.
#
# 4. Evalúe ambos modelos sobre el conjunto de prueba mediante el C-index.
#
# 5. Para el modelo DeepSurv, presente:
#    - Gráfica de la pérdida de entrenamiento y validación.
#    - Curvas de supervivencia estimadas para al menos tres individuos.
#
# 6. Presente una tabla comparativa con el C-index de ambos modelos.
#
# 7. Escriba una conclusión breve indicando:
#    - Qué modelo obtuvo mejor desempeño.
#    - Si DeepSurv produjo una mejora relevante frente al modelo de Cox.
#    - Qué posibles razones explican los resultados obtenidos.
#
# ### Entrega
#
# Entregue el notebook ejecutado, incluyendo el código, las gráficas, la tabla comparativa y la interpretación de los resultados.
